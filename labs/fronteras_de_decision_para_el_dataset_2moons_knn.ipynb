# %% [markdown]
# # Fronteras de decisión para el dataset artificial 2moons usando k-NN

# %% [markdown]
# El siguiente es un conjunto artificial de datos que tiene una frontera de decisión compleja.

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt

NPOINTS = 140

X, y = make_moons(
    n_samples=NPOINTS, 
    shuffle=False, 
    noise=0.1, 
    random_state=12345)

plt.scatter(X[:70,0], X[:70,1], color='red')
plt.scatter(X[70:,0], X[70:,1], color='blue')
plt.gca().set_aspect('equal', adjustable='box')

# %% [markdown]
# Construya un clasificador usando vecinos más cercanos (determine el k óptimo) y grafique las fronteras de decisión.
#
# Ayuda: https://scikit-learn.org/stable/auto_examples/neighbors/plot_classification.html#sphx-glr-auto-examples-neighbors-plot-classification-py
