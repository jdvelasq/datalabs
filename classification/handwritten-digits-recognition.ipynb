# %% [markdown]
# <a href="https://colab.research.google.com/github/jdvelasq/notebooks/blob/master/classification/hadwritten-digits-recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reconocimiento de dígitos escritos a mano.
# ===

# %% [markdown]
# Consiste en 1797 instancias de imágenes de dígitos escritos a mano.
#
# https://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits

# %% [markdown]
# Desarrolle un modelo de clasificación que permita determinar a que dígito pertenece cada imágen.

# %%
##
## Preparacion
##
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn import datasets

## carga del dataset
digits = datasets.load_digits()

##
## digits.data contiene el patrón de entrada
## digits.target es la clase
##

## Matriz de la entrada
print(type(digits.data))
print(digits.data.shape)

# %%
print(type(digits.target))
len(digits.target)

# %%
##
## Primeras 10 imágenes del dataset
##
images_and_labels = list(zip(digits.images, digits.target))
for index, (image, label) in enumerate(images_and_labels[:10]):
    plt.subplot(2, 5, index + 1)
    plt.axis('off')
    plt.imshow(image, cmap=plt.cm.gray_r, interpolation='nearest')
    plt.title('Training: %i' % label)

# %% [markdown]
# ---
