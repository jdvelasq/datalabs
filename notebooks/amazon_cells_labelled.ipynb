# %% [markdown]
# <a href="https://colab.research.google.com/github/jdvelasq/playground/blob/master/notebooks/
#          amazon_cells_labelled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Análisis de sentimientos de ventas en Amazon
# ===
#
# * *60 min*

# %% [markdown]
# EL siguiente archivo contiene las revisiones de productos vendidos en amazon.com. Estas están calificadas como positvas y negativas. Construya un sistema de análisis de sentimientos para determinar si la experiencia del usuario fue positiva o negativa.

# %%
##
## Preparacion
##
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/jdvelasq/notebooks/master/amazon_cells_labelled.tsv",
    sep = '\t',           
    thousands = None,    
    decimal = '.',       
    encoding='latin-1')

# %%
df.info()

# %%
df.columns

# %% [markdown]
# ---
